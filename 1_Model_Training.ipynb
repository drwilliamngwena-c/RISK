# %% [markdown]
# # Credit Risk Model Training
# Baseline models for PD, LGD, and EAD.

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression
# Training logic...
print('Models Trained.')
