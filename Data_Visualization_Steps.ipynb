# %% [markdown]
# # Data Visualization Steps
# This notebook contains the visual analysis of credit risk features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing Income Distribution
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['person_income'], kde=True, color='blue')
plt.title('Income Distribution (Capped)')
plt.subplot(1, 2, 2)
sns.boxplot(x=df['person_income'], color='lightgreen')
plt.title('Income Boxplot')
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='person_home_ownership', hue='loan_status')
plt.title('Loan Status by Home Ownership')
plt.show()

# %% [markdown]
# ### Interpretation
# - Outliers have been capped to stabilize the model.
# - Home ownership shows a correlation with default frequency.
