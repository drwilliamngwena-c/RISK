# %% [markdown]
# # Dataset Definition and Understanding
#
# This notebook outlines the dataset structure for credit risk modeling, focusing on the three pillars of Basel II/III: PD, LGD, and EAD.

# %% [markdown]
# ### 1. Structure of the Dataset
# The dataset typically consists of historical loan data containing:
# * **Static Information**: Borrower demographics.
# * **Loan Attributes**: Loan details.
# * **Behavioral Data**: Payment history.
# * **Economic Indicators**: Macro factors.

# %% [markdown]
# ### 2. Variable Definitions
#
# | Variable Category | Description |
# | :--- | :--- |
# | **Demographics** | age, income, home_ownership |
# | **Credit History** | score, history, incidents |

# %% [markdown]
# ### 3. Target Variable Identification
# 1. PD: `is_default`
# 2. LGD: `recovery_rate`
# 3. EAD: `total_exposure`

# %%
import pandas as pd
import numpy as np

data_schema = {
    'loan_id': 'Unique identifier',
    'loan_status': 'Target for PD',
    'recovery_amount': 'Used for LGD'
}

for col, desc in data_schema.items():
    print(f'{col}: {desc}')
