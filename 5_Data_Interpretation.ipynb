# %% [markdown]
# # Interpretation of Data Preprocessing Results

# %% [markdown]
# ### Summary of Findings
# 1. **Outlier Mitigation**: Capping at the 99th percentile normalized income data.
# 2. **Feature Correlation**: Home ownership shows a direct link to default rates in the PD target variable.
# 3. **Encoding**: One-hot encoding maintained logical consistency for modeling.
